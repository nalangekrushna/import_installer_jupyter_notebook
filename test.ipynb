# %%
from tqdm.tqdm_notebook import tqdm    # already there
import click                             # new install 
from threadpoolctl import threadpool_info   # new install with different way.

# %% [markdown]
# # just for fun testing

# %% [raw]
# hwo r u

# %%
import numpy as np 
import pandas as pd
np.array([123])

# %%
# import me just for fun.

# %%
import re
txt = 'from tqdm.tqdm_notebook import tqdm    # already there'
txt
re.search('from \w+',txt).group(0).split()[1]
# Out:
# 'tqdm'

# %%
c = set()
import pkgutil
for i in pkgutil.iter_modules(None): 
    c.add(i[1])

# %%
import sys
a = sys.builtin_module_names
print(a)
# Out:
# ('_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_imp', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha256', '_sha3', '_sha512', '_signal', '_sre', '_stat', '_string', '_struct', '_symtable', '_thread', '_tracemalloc', '_warnings', '_weakref', '_winapi', 'array', 'atexit', 'audioop', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'parser', 'sys', 'time', 'winreg', 'xxsubtype', 'zipimport', 'zlib')

# %%
dir (__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
import pkgutil

for i in pkgutil.walk_packages() :
    print(i)
# Out:
# ModuleInfo(module_finder=FileFinder('D:\\Project\\import downloader notebook'), name='main', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_asyncio', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_bz2', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_ctypes', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_ctypes_test', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_decimal', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_elementtree', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_hashlib', ispkg=False)
# ModuleInfo(module_finder=FileFinder('C:\\Users\\nalan\\Anaconda3\\DLLs'), name='_lzma', ispkg=False)
# ...

# %%
lib = list(sys.modules.keys())
lib_set = set([ key.split('.')[0] for key in lib if not key.startswith('_') ])        

print(len(lib))
print(len(lib_set))
print(lib_set)
# Out:
# 757
# 154
# ...

# %%
pip
# Out:
# Usage:
#   C:\Users\nalan\Anaconda3\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
# ...

# %%
a = {'pandas', 'sys', 'threadpoolctl', 'pkgutil', 'numpy', 're', 'tqdm', 'click'}
b = {'winreg', 'zipimport', 'pygments', 'warnings', 'distutils', 're', 'nt', 'contextlib', 'ntpath', 'atexit', 'bisect', 'mimetypes', 'dis', 'selectors', 'prompt_toolkit', 'abc', 'glob', 'backcall', 'opcode', 'email', 'token', 'http', 'operator', 'threading', 'sre_compile', 'ast', 'pprint', 'zmq', 'socket', 'imp', 'tornado', 'uuid', 'platform', 'string', 'mpl_toolkits', 'asyncio', 'difflib', 'site', 'json', 'enum', 'ntsecuritycon', 'tempfile', 'IPython', 'struct', 'builtins', 'quopri', 'io', 'concurrent', 'signal', 'profile', 'jupyter_core', 'faulthandler', 'cProfile', 'dateutil', 'getopt', 'os', 'pkgutil', 'nturl2path', 'runpy', 'pydoc', 'sre_parse', 'random', 'shutil', 'errno', 'collections', 'types', 'tokenize', 'html', 'calendar', 'functools', 'uu', 'six', 'pdb', 'colorama', 'pydoc_data', 'decimal', 'binascii', 'pickleshare', 'code', 'pathlib', 'pickle', 'marshal', 'hmac', 'sre_constants', 'zlib', 'ipywidgets', 'copy', 'lzma', 'gc', 'linecache', 'numbers', 'time', 'locale', 'xml', 'genericpath', 'codecs', 'google', 'ctypes', 'win32security', 'copyreg', 'jedi', 'urllib', 'getpass', 'shlex', 'stat', 'sphinxcontrib', 'bz2', 'timeit', 'argparse', 'subprocess', 'posixpath', 'codeop', 'importlib', 'hashlib', 'jupyter_client', 'wcwidth', 'fnmatch', 'weakref', 'datetime', 'pstats', 'cython_runtime', 'decorator', 'msvcrt', 'array', 'reprlib', 'win32api', 'select', 'sys', 'cmd', 'encodings', 'unicodedata', 'traceback', 'keyword', 'storemagic', 'sqlite3', 'heapq', 'colorsys', 'filecmp', 'typing', 'parso', 'bdb', 'itertools', 'traitlets', 'math', 'ssl', 'gettext', 'queue', 'textwrap', 'ipykernel', 'base64', 'logging', 'contextvars', 'inspect', 'ipython_genutils'}
a - b
# Out:
# {'click', 'numpy', 'pandas', 'threadpoolctl', 'tqdm'}

# %%
'ipython_genutils._version'.split('.')[1]
# Out:
# '_version'

# %%
len(c)
len(b)
d = c | b
len(d)
# Out:
# 621

# %%
len(b)
# Out:
# 154

# %%
lib_set = set([ key.split('.')[0] for key in sys.modules if not key.startswith('_') ])
print(' '.join(lib_set))
# Out:
# builtins uuid email ast pprint bisect struct runpy nturl2path dateutil subprocess heapq bz2 profile opcode code storemagic unicodedata reprlib time zmq ntpath types uu re decorator token dis html atexit array urllib base64 stat codeop hashlib ctypes http operator cProfile timeit winreg genericpath fnmatch prompt_toolkit quopri traceback pkgutil win32api select selectors backcall sys xml zipimport math concurrent contextvars codecs threading pickle abc io pstats win32security itertools jupyter_client site tokenize textwrap numbers mpl_toolkits inspect colorama pathlib collections pydoc shlex argparse contextlib ssl tornado posixpath getpass ipywidgets warnings difflib netifaces lzma decimal encodings platform sre_compile calendar pdb IPython shutil typing colorsys wcwidth gettext linecache traitlets getopt sre_parse signal asyncio weakref parso cmd string functools keyword nt mimetypes gc sqlite3 zlib os logging hmac errno marshal msvcrt bdb binascii json six enum sphinxcontrib locale
# ...

# %%
lib_set
# Out:
# {'IPython',
#  'abc',
#  'argparse',
#  'array',
#  'ast',
#  'asyncio',
#  'atexit',
#  'backcall',
#  'base64',
#  'bdb',
#  'binascii',
#  'bisect',
#  'builtins',
#  'bz2',
#  'cProfile',
#  'calendar',
#  'cmd',
#  'code',
#  'codecs',
#  'codeop',
#  'collections',
#  'colorama',
#  'colorsys',
#  'concurrent',
#  'contextlib',
#  'contextvars',
#  'copy',
#  'copyreg',
#  'ctypes',
#  'cython_runtime',
#  'datetime',
#  'dateutil',
#  'decimal',
#  'decorator',
#  'difflib',
#  'dis',
#  'distutils',
#  'email',
#  'encodings',
#  'enum',
#  'errno',
#  'faulthandler',
#  'filecmp',
#  'fnmatch',
#  'functools',
#  'gc',
#  'genericpath',
#  'getopt',
#  'getpass',
#  'gettext',
#  'glob',
#  'google',
#  'hashlib',
#  'heapq',
#  'hmac',
#  'html',
#  'http',
#  'imp',
#  'importlib',
#  'inspect',
#  'io',
#  'ipykernel',
#  'ipython_genutils',
#  'ipywidgets',
#  'itertools',
#  'jedi',
#  'json',
#  'jupyter_client',
#  'jupyter_core',
#  'keyword',
#  'linecache',
# ...

# %%
pip --version
# Out:
# pip 19.2.3 from C:\Users\KNTX_PUNE_010\Anaconda3\lib\site-packages\pip (python 3.7)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.modules
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7ac4a9c53e0a> in <module>
#       1 import os
# ----> 2 os.modules
#
# AttributeError: module 'os' has no attribute 'modules'

# %%
import sys
sys.modules.keys()
# Out:
# dict_keys(['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp1252', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'google', 'mpl_toolkits', 'sphinxcontrib', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre
# ...

# %%
import subprocess
lst = ['dfdfd', 'asfdsfsdfds']
l = {'numpy','pandas','sklearn'}
a = '", "'.join(l)
b = '"'+a+'"'
b
subprocess.check_call([sys.executable, "-m", "pip", "install", b])
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-17-4eb5859332dd> in <module>
#       5 b = '"'+a+'"'
#       6 b
# ----> 7 subprocess.check_call([sys.executable, "-m", "pip", "install", b])
#
# ~\Anaconda3\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     345         if cmd is None:
#     346             cmd = popenargs[0]
# --> 347         raise CalledProcessError(retcode, cmd)
#     348     return 0
#     349
#
# CalledProcessError: Command '['C:\\Users\\KNTX_PUNE_010\\Anaconda3\\python.exe', '-m', 'pip', 'install', '"numpy", "pandas", "sklearn"']' returned non-zero exit status 1.

# %%
from jupyter_installer import run
run('Utils.ipynb')
# Out:
# dict_keys(['cells', 'metadata', 'nbformat', 'nbformat_minor'])
# package list to import {'os', 'io', 'google_auth_oauthlib', 'pickle', 'google', 'googleapiclient'}
# all packages are available so no package will be installed.
